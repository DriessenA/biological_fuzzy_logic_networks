# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
fontsize = 12

# %%
sns.set_theme(font="Arial", style="ticks", rc={"font.size": fontsize,"axes.titlesize":fontsize,"axes.labelsize":fontsize, 
                                               "xtick.labelsize": fontsize, "ytick.labelsize": fontsize, "legend.fontsize": fontsize})
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"
mpl.rcParams['font.size'] = fontsize

mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["#D55E00", "#0072B2", "#F0E442", "#56B4E9"])

# %%
rmse = pd.read_csv("/dccstor/ipc1/CAR/BFN/Model/CNoRFuzzy/RMSE_df.csv", index_col=0).T.reset_index(drop=False)
rmse
# Out:
#    index    map3k7         mek12        map3k1          mkk4  igf1       ikk  \
# 0      0  0.238515  1.110223e-16  4.965068e-17  4.965068e-17   0.0  0.028075
# 1      1  0.413120  9.930137e-17  0.000000e+00  0.000000e+00   0.0  0.048628
# 2      2  0.337311  8.599751e-17  0.000000e+00  0.000000e+00   0.0  0.039705
# 3      3  0.238515  8.599751e-17  0.000000e+00  0.000000e+00   0.0  0.028075
# 4      4  0.238515  7.021667e-17  0.000000e+00  0.000000e+00   0.0  0.028075
# ..   ...       ...           ...           ...           ...   ...       ...
# 95    95  0.238515  8.599751e-17  0.000000e+00  0.000000e+00   0.0  0.028075
# 96    96  0.337311  7.021667e-17  0.000000e+00  0.000000e+00   0.0  0.039705
# 97    97  0.238515  1.110223e-16  0.000000e+00  0.000000e+00   0.0  0.028075
# 98    98  0.238515  8.599751e-17  0.000000e+00  0.000000e+00   0.0  0.028075
# 99    99  0.238515  7.021667e-17  0.000000e+00  0.000000e+00   0.0  0.028075
#
# ...

# %%
plt_data = rmse.melt(id_vars="index", var_name="node", value_name="RMSE")
plt_data["MSE"] = plt_data["RMSE"]**2

# %%
sns.boxplot(data=plt_data, y="node", x="RMSE")
# Out:
# <AxesSubplot:xlabel='RMSE', ylabel='node'>
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial

# %%
sns.boxplot(data=plt_data, y="node", x="MSE")
plt.savefig("/dccstor/ipc1/CAR/BFN/Figures/CNoRFuzzy_100CV.pdf", bbox_inches="tight")

# %%
rmse
# Out:
#    index    map3k7         mek12        map3k1          mkk4  igf1       ikk  \
# 0      0  0.238515  1.110223e-16  4.965068e-17  4.965068e-17   0.0  0.028075
# 1      1  0.413120  9.930137e-17  0.000000e+00  0.000000e+00   0.0  0.048628
# 2      2  0.337311  8.599751e-17  0.000000e+00  0.000000e+00   0.0  0.039705
# 3      3  0.238515  8.599751e-17  0.000000e+00  0.000000e+00   0.0  0.028075
# 4      4  0.238515  7.021667e-17  0.000000e+00  0.000000e+00   0.0  0.028075
# ..   ...       ...           ...           ...           ...   ...       ...
# 95    95  0.238515  8.599751e-17  0.000000e+00  0.000000e+00   0.0  0.028075
# 96    96  0.337311  7.021667e-17  0.000000e+00  0.000000e+00   0.0  0.039705
# 97    97  0.238515  1.110223e-16  0.000000e+00  0.000000e+00   0.0  0.028075
# 98    98  0.238515  8.599751e-17  0.000000e+00  0.000000e+00   0.0  0.028075
# 99    99  0.238515  7.021667e-17  0.000000e+00  0.000000e+00   0.0  0.028075
#
# ...

# %%
plt_data
# Out:
#      index    node      RMSE       MSE
# 0        0  map3k7  0.238515  0.056889
# 1        1  map3k7  0.413120  0.170668
# 2        2  map3k7  0.337311  0.113779
# 3        3  map3k7  0.238515  0.056889
# 4        4  map3k7  0.238515  0.056889
# ...    ...     ...       ...       ...
# 1695    95     ikb  0.001520  0.000002
# 1696    96     ikb  0.002150  0.000005
# 1697    97     ikb  0.001520  0.000002
# 1698    98     ikb  0.001520  0.000002
# 1699    99     ikb  0.001520  0.000002
#
# [1700 rows x 4 columns]
