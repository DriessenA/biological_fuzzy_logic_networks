# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from biological_fuzzy_logic_networks.manuscripts_functions.colors import default_colors

# %%
result1 = pd.read_csv("/Users/adr/Box/BioFuzzNet/BFN/Model/Scaling/100_to_100000_output_times.csv", index_col=0)
result2 = pd.read_csv("/Users/adr/Box/BioFuzzNet/BFN/Model/Scaling/1000000_output_times.csv", index_col=0)

# %%
result1 = result1.rename(columns={"100000": 'Number of cells'})
result2 = result2.rename(columns={"n_cells": 'Number of cells'})

result = pd.concat([result1, result2])
result
# Out:
#            time  Number of cells
# 0     17.914935              100
# 1     44.649781             1000
# 2    424.943430            10000
# 3   4341.446567           100000
# 0  33530.904784          1000000

# %%
sns.lineplot(data=result, x="Number of cells", y="time", label="BioFuzzNet", c=default_colors["orange"])
sns.lineplot(x=result["Number of cells"], y=result["Number of cells"], label="Linear scaling", 
             linestyle="dashed", c="grey")
plt.xscale("log")
plt.yscale("log")
t = plt.ylabel("Time in seconds")
plt.savefig("/Users/adr/Box/BioFuzzNet/Figures/Scaling_cells.pdf")
