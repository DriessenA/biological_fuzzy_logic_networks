# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
sns.set_theme(font="Arial", style="ticks", rc={"font.size": 8,"axes.titlesize":8,"axes.labelsize":8, 
                                               "xtick.labelsize": 8, "ytick.labelsize": 8, "legend.fontsize": 8})
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"
mpl.rcParams['font.size'] = 8
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["#D55E00", "#0072B2", "#F0E442", "#56B4E9"])

# %%
rmse = pd.read_csv("/dccstor/ipc1/CAR/BFN/Model/CNoRFuzzy/RMSE_df.csv", index_col=0).T.reset_index(drop=False)

# %%
plt_data = rmse.melt(id_vars="index", var_name="node", value_name="RMSE")

# %%
sns.boxplot(data=plt_data, y="node", x="RMSE")
# Out:
# <AxesSubplot:xlabel='RMSE', ylabel='node'>

# %%
rmse
# Out:
#     index Unnamed: 0             0             1             2             3  \
# 0       0     map3k7  2.385149e-01  4.131199e-01  3.373110e-01  2.385149e-01
# 1       1      mek12  8.599751e-17  9.930137e-17  8.599751e-17  8.599751e-17
# 2       2     map3k1  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 3       3       mkk4  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4       4       igf1  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 5       5        ikk  2.807544e-02  4.862809e-02  3.970467e-02  2.807544e-02
# 6       6        akt  4.031100e-02  5.296814e-02  3.720917e-02  5.854429e-02
# 7       7        p38  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 8       8       tgfa  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 9       9       pi3k  1.227836e-01  1.474884e-01  1.151499e-01  1.654797e-01
# 10     10        ras  8.599751e-17  9.930137e-17  8.599751e-17  8.599751e-17
# ...

# %%
plt_data
# Out:
#       index        node     RMSE
# 0         0  Unnamed: 0   map3k7
# 1         1  Unnamed: 0    mek12
# 2         2  Unnamed: 0   map3k1
# 3         3  Unnamed: 0     mkk4
# 4         4  Unnamed: 0     igf1
# ...     ...         ...      ...
# 1712     12          99      0.0
# 1713     13          99      0.0
# 1714     14          99      0.0
# 1715     15          99      0.0
# 1716     16          99  0.00152
#
# [1717 rows x 3 columns]
