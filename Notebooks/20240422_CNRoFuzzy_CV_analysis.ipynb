# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
sns.set_theme(font="Arial", style="ticks", rc={"font.size": 8,"axes.titlesize":8,"axes.labelsize":8, 
                                               "xtick.labelsize": 8, "ytick.labelsize": 8, "legend.fontsize": 8})
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"
mpl.rcParams['font.size'] = 8
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["#D55E00", "#0072B2", "#F0E442", "#56B4E9"])

# %%
rmse = pd.read_csv("/dccstor/ipc1/CAR/BFN/Model/CNoRFuzzy/RMSE_df.csv", index_col=0).reset_index(drop=False)
rmse
# Out:
#     index    map3k7     mek12    map3k1      mkk4  igf1       ikk       akt  \
# 0       0  0.280967  0.523481  0.225673  0.120624   0.0  0.688699  0.646819
# 1       1  0.270653  0.600906  0.098589  0.085778   0.0  0.437071  0.437221
# 2       2  0.282997  0.456704  0.119997  0.104476   0.0  0.369132  0.482075
# 3       3  0.253779  0.386408  0.117750  0.105659   0.0  0.413917  0.537418
# 4       4  0.259461  0.335688  0.099427  0.105110   0.0  0.463667  0.434658
# ..    ...       ...       ...       ...       ...   ...       ...       ...
# 95     95  0.168150  0.378180  0.117400  0.104889   0.0  0.462702  0.442649
# 96     96  0.190855  0.374929  0.120469  0.102649   0.0  0.380565  0.393481
# 97     97  0.230505  0.532385  0.132904  0.104156   0.0  0.430688  0.603697
# 98     98  0.190569  0.393501  0.120486  0.103635   0.0  0.428383  0.436875
# 99     99  0.163674  0.333600  0.121283  0.105008   0.0  0.533476  0.468304
#
#          p38  tgfa      pi3k       ras  il1a     erk12  tnfa     hsp27  \
# 0   0.017999   0.0  0.180906  0.320371   0.0  0.032655   0.0  0.442156
# 1   0.007633   0.0  0.230202  0.372939   0.0  0.033424   0.0  0.771783
# 2   0.009649   0.0  0.115666  0.321957   0.0  0.030744   0.0  0.627419
# 3   0.010121   0.0  0.100150  0.347437   0.0  0.028945   0.0  0.442228
# 4   0.007906   0.0  0.111812  0.287493   0.0  0.028347   0.0  0.445616
# ..       ...   ...       ...       ...   ...       ...   ...       ...
# 95  0.001462   0.0  0.097478  0.348920   0.0  0.038050   0.0  0.445303
# 96  0.004233   0.0  0.168189  0.288577   0.0  0.036150   0.0  0.626752
# 97  0.012789   0.0  0.162204  0.393138   0.0  0.020252   0.0  0.445092
# 98  0.011906   0.0  0.159565  0.342412   0.0  0.030646   0.0  0.445310
# 99  0.012908   0.0  0.160228  0.291718   0.0  0.028402   0.0  0.445606
#
#        jnk12       ikb
# 0   0.020209  0.001509
# 1   0.015910  0.043413
# 2   0.018651  0.442002
# 3   0.013563  0.447216
# 4   0.016751  0.447216
# ..       ...       ...
# 95  0.016873  0.447216
# 96  0.018629  0.001328
# 97  0.018925  0.452069
# 98  0.019775  0.447216
# 99  0.018105  0.447216
#
# [100 rows x 18 columns]

# %%
plt_data = rmse.melt(id_vars="index", var_name="node", value_name="RMSE")

# %%
sns.boxplot(data=plt_data, y="node", x="RMSE")
# Out:
# <AxesSubplot:xlabel='RMSE', ylabel='node'>
