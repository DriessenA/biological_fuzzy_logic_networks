# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
test_cell_lines = ["BT20",
                   "BT474",
                   "CAL148",
                   "CAL51",
                   "CAL851",
                   "DU4475",
                   "EFM192A",
                   "EVSAT",
                   "HBL100",
                   "HCC1599",
                   "HCC2185",
                   "HCC3153",
                   "HDQP1",
                   "JIMT1",
                   "MCF7",
                   "MDAMB157",
                   "MDAMB175VII",
                   "MDAMB415",
                   "MFM223",
                   "MPE600",
                   "MX1",
                   "OCUBM",
                   "UACC812",
                   "ZR7530"]

data_dir = "/dccstor/ipc1/CAR/DREAM/DREAMdata/Time_aligned_per_cell_line/CL_incl_test/"

wanted_treatments = set(['EGF', 'full', 'iEGFR', 'iMEK', 'iPI3K', 'iPKC', 'imTOR'])
wanted_time = set([0.,   5.5,  7.,   9.,  13.,  17.,  23.,  30.,  40.,  60., ])
na_markers = set(['p.HER2', 'p.PLCg2'])
markers = ['b.CATENIN', 'cleavedCas', 'CyclinB',
       'GAPDH', 'IdU', 'Ki.67', 'p.4EBP1', 'p.Akt.Ser473.', 'p.AKT.Thr308.',
       'p.AMPK', 'p.BTK', 'p.CREB', 'p.ERK', 'p.FAK', 'p.GSK3b', 'p.H3',
       'p.HER2', 'p.JNK', 'p.MAP2K3', 'p.MAPKAPK2', 'p.MEK', 'p.MKK3.MKK6',
       'p.MKK4', 'p.NFkB', 'p.p38', 'p.p53', 'p.p90RSK', 'p.PDPK1', 'p.PLCg2',
       'p.RB', 'p.S6', 'p.S6K', 'p.SMAD23', 'p.SRC', 'p.STAT1', 'p.STAT3',
       'p.STAT5']

# %%
for cl in test_cell_lines:
    data = pd.read_csv(f"{data_dir}{cl}.csv")
    print(data["cell_line"].unique())
    print("Treatment check: ", set(data["treatment"].unique())==wanted_treatments)
    print("Time check: ", set(data["time"].unique()) == wanted_time)
    print("NA markers check: ", set(data.columns[data.isna().sum() >0 ].values) == na_markers)
    print("Data range: ", data[markers].max().max(), data[markers].min().min())
# Out:
# ['BT20']
# Treatment check:  True
# Time check:  True
# NA markers check:  True
# Data range:  13.46027 -0.61995863
# ['BT474']
# Treatment check:  True
# Time check:  True
# NA markers check:  True
# Data range:  13.86663 -0.61995863
# ['CAL148']
# Treatment check:  True
# Time check:  True
# NA markers check:  True
# Data range:  14.00633 -0.61995863
# ['CAL51']
# Treatment check:  True
# Time check:  True
# NA markers check:  True
# Data range:  13.84126 -0.61995863
# ['CAL851']
# Treatment check:  True
# Time check:  True
# NA markers check:  True
# Data range:  13.50536 -0.61995863
# ['DU4475']
# Treatment check:  True
# Time check:  True
# NA markers check:  True
# Data range:  13.91675 -0.61995863
# ['EFM192A']
# Treatment check:  True
# Time check:  True
# NA markers check:  True
# Data range:  13.69669 -0.61995863
# ['EVSAT']
# Treatment check:  True
# Time check:  True
# NA markers check:  True
# Data range:  14.20363 -0.61995863
# ['HBL100']
# Treatment check:  True
# ...

# %%
data = pd.read_csv(f"{data_dir}MCF7.csv")

# %%
data = data[data["time"]==9]
data = data[data["treatment"]=="EGF"]

# %%
for marker in markers:
    print(marker, sum(data[marker]==0))
# Out:
# b.CATENIN 0
# cleavedCas 0
# CyclinB 0
# GAPDH 0
# IdU 0
# Ki.67 0
# p.4EBP1 0
# p.Akt.Ser473. 0
# p.AKT.Thr308. 0
# p.AMPK 0
# p.BTK 0
# p.CREB 0
# p.ERK 0
# p.FAK 0
# p.GSK3b 0
# p.H3 0
# p.HER2 0
# p.JNK 0
# p.MAP2K3 0
# p.MAPKAPK2 0
# p.MEK 0
# p.MKK3.MKK6 0
# p.MKK4 0
# p.NFkB 0
# p.p38 0
# p.p53 0
# p.p90RSK 0
# p.PDPK1 0
# p.PLCg2 0
# p.RB 0
# p.S6 0
# p.S6K 0
# p.SMAD23 0
# p.SRC 0
# p.STAT1 0
# p.STAT3 0
# p.STAT5 0

# %%
data.shape
# Out:
# (19086, 40)
