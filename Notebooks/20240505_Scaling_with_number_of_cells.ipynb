# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from biological_fuzzy_logic_networks.

# %%
result1 = pd.read_csv("/Users/adr/Box/BioFuzzNet/BFN/Model/Scaling/100_to_100000_output_times.csv", index_col=0)
result2 = pd.read_csv("/Users/adr/Box/BioFuzzNet/BFN/Model/Scaling/1000000_output_times.csv", index_col=0)

# %%
result1 = result1.rename(columns={"100000": 'Number of cells'})
result2 = result2.rename(columns={"n_cells": 'Number of cells'})

result = pd.concat([result1, result2])
result

# %%
sns.lineplot(data=result, x="Number of cells", y="time", label="BioFuzzNet")
sns.lineplot(x=result["Number of cells"], y=result["Number of cells"], label="Linear scaling")
plt.xscale("log")
plt.yscale("log")
t = plt.ylabel("Time in seconds")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 sns.lineplot(data=result, x="Number of cells", y="time", label="BioFuzzNet")
# ----> 2 sns.lineplot(x=result["Number of cells"], y=result["Number of cells"], label="Linear scaling", style="--")
#       3 plt.xscale("log")
#       4 plt.yscale("log")
#
# File ~/miniconda3/envs/biofuzznet/lib/python3.10/site-packages/seaborn/relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
# ...
